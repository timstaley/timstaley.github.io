# %%
#ignore
# %matplotlib inline

# %% [markdown]
# A demo notebook for testing out the [pelican-ipynb](https://github.com/danielfrg/pelican-ipynb) plugin.

# %%
foo = 123

# %% [markdown]
# # Bar

# %%
import seaborn
import numpy as np

# %%
seaborn.distplot(np.random.normal(size=100));
